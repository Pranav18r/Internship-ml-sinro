# %% [markdown]
# Logistic Regression

# %%
# Creating a house price prediction model using linear regression

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix,precision_score,recall_score,f1_score
from sklearn.preprocessing import OneHotEncoder


df = pd.read_csv('C:/Users/Amal/OneDrive/Documents/Internship/Machine Learning/Classification/Logistic Regression/loanfile.csv')
data = pd.DataFrame(df)

print(data.head())

print(data.info())

# One hot encoding

ohe = OneHotEncoder(handle_unknown='ignore',sparse_output=False).set_output(transform='pandas')
ohetransform = ohe.fit_transform(df[['Gender','Married','Dependents','Education','Self_Employed','ApplicantIncome','CoapplicantIncome','LoanAmount','Loan_Amount_Term','Credit_History','Property_Area']])
print(ohetransform)

df = pd.concat([df, ohetransform], axis='columns')

df.drop(
    ['Gender','Married','Dependents','Education','Self_Employed','ApplicantIncome','CoapplicantIncome','LoanAmount','Loan_Amount_Term','Credit_History','Property_Area'],
    axis='columns',
    inplace=True
)
print(df.head())

x = df.drop('Loan_Status', axis='columns')
y = df['Loan_Status']

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)   # 0nly 20% data will be test data

print(x_train.shape)
print(x_test.shape)


print(data.std())  # checking the standarisation

scaler = StandardScaler()    # Standarising the dataset
scaler.fit(x_train)

x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

print(x_train.std())  # checking the standarisation
print(x_test.std())    # checking the standarisation

model = LogisticRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
print(y_pred)

# Comparison between ac
comparison = pd.DataFrame({'Actual':y_test, 'Predicted':y_pred})
print(comparison.head())

# Evalute model performance
print("Accuracy", accuracy_score(y_test,y_pred))
print("Confusion Matrix", confusion_matrix(y_test,y_pred))
print("Precision", precision_score(y_test,y_pred))
print("Recall", recall_score(y_test,y_pred))
print("F1 Score", f1_score(y_test,y_pred))

# visualisation

plt.scatter(x_test,y_test, color='blue')
plt.plot(x_test,y_pred, color='red')
plt.xlabel('Median Income')
plt.ylabel('Price')
plt.title('Lasso Regularisation')
plt.show()

# %% [markdown]
# K Nearest Neighbour

# %%
# K-Nearest Neighbors Classification using Iris Dataset

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import (accuracy_score,confusion_matrix,precision_score,recall_score,f1_score)

df = pd.read_csv(
    'C:/Users/Amal/OneDrive/Documents/Internship/Python/Data Preprocessing/iris_data.csv'
)

data = pd.DataFrame(df)

print(data.head())
print(data.info())

# Handle missing values
data.fillna(data.mean(numeric_only=True), inplace=True)

# Remove ID column
if 'Id' in data.columns:
    data.drop('Id', axis=1, inplace=True)

# Encode target column
le = LabelEncoder()

data['Species'] = le.fit_transform(data['Species'])

print(data.head())

# Features and Target
x = data.drop('Species', axis=1)
y = data['Species']

# Train Test Split
x_train, x_test, y_train, y_test = train_test_split(
    x,
    y,
    test_size=0.2,
    random_state=42
)

print(x_train.shape)
print(x_test.shape)

# Standardization
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

model = KNeighborsClassifier(n_neighbors=5)
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

print(y_pred)

comparison = pd.DataFrame({
    'Actual': y_test,
    'Predicted': y_pred
})

print(comparison.head())

# Evaluation Metrics
print("Accuracy :", accuracy_score(y_test, y_pred))
print("Confusion Matrix :")
print(confusion_matrix(y_test, y_pred))
print("Precision :",precision_score(y_test, y_pred, average='weighted'))
print("Recall :",recall_score(y_test, y_pred, average='weighted'))
print("F1 Score :",f1_score(y_test, y_pred, average='weighted'))

# %% [markdown]
# Decision Tree Classification

# %%
# Decision Tree Classification using Student Exam Dataset

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import (accuracy_score,confusion_matrix,precision_score,recall_score,f1_score)

df = pd.read_csv('C:\\Users\\Amal\\OneDrive\\Documents\\Internship\\Machine Learning\\Regression\\Linear\\student_exam.csv')

data = pd.DataFrame(df)

print(data.head())
print(data.info())
# Handle missing values
data.fillna(data.mean(numeric_only=True), inplace=True)

# Features and Target
x = data.drop('Pass/Fail', axis=1)
y = data['Pass/Fail']

# Train Test Split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)

print(x_train.shape)
print(x_test.shape)

# Standardization
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

model = DecisionTreeClassifier()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
print(y_pred)

comparison = pd.DataFrame({
    'Actual': y_test,
    'Predicted': y_pred
})

print(comparison.head())

# Evaluation Metrics
print("Accuracy :", accuracy_score(y_test, y_pred))
print("Confusion Matrix :")
print(confusion_matrix(y_test, y_pred))
print("Precision :",precision_score(y_test, y_pred, average='weighted'))
print("Recall :",recall_score(y_test, y_pred, average='weighted'))
print("F1 Score :",f1_score(y_test, y_pred, average='weighted'))

# %% [markdown]
# Random Forest

# %%
# Random Forest  Classification using Telecom Customer Churn Dataset
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score
from sklearn.preprocessing import OneHotEncoder

df = pd.read_csv('C:/Users/Amal/OneDrive/Documents/Internship/Python/Data Preprocessing/Handling Imbalanced Data/telco_customer_churn.csv')

data = pd.DataFrame(df)

print(data.head())
print(data.info())

data['Churn'] = data['Churn'].astype(str).str.strip()
data['Churn'] = data['Churn'].map({'Yes': 1, 'No': 0})

data.dropna(subset=['Churn'], inplace=True)

categorical_cols = ['gender','Partner','Dependents','PhoneService','MultipleLines','InternetService','OnlineSecurity','OnlineBackup','DeviceProtection','TechSupport','StreamingTV','StreamingMovies','Contract','PaperlessBilling','PaymentMethod']

data['TotalCharges'] = pd.to_numeric(data['TotalCharges'], errors='coerce')

data.fillna(data.mean(numeric_only=True), inplace=True)

ohe = OneHotEncoder(
    handle_unknown='ignore',
    sparse_output=False
).set_output(transform='pandas')

ohetransform = ohe.fit_transform(data[categorical_cols])

data = pd.concat([data, ohetransform], axis=1)

data.drop(categorical_cols, axis=1, inplace=True)

if 'customerID' in data.columns:
    data.drop('customerID', axis=1, inplace=True)

print(data.head())

x = data.drop('Churn', axis=1)
y = data['Churn']

x_train, x_test, y_train, y_test = train_test_split(
    x,
    y,
    test_size=0.2,
    random_state=42
)

print(x_train.shape)
print(x_test.shape)

scaler = StandardScaler()

x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

model = RandomForestClassifier()

model.fit(x_train, y_train)

y_pred = model.predict(x_test)

print(y_pred)

comparison = pd.DataFrame({
    'Actual': y_test,
    'Predicted': y_pred
})

print(comparison.head())

print("Accuracy :", accuracy_score(y_test, y_pred))
print("Confusion Matrix :")
print(confusion_matrix(y_test, y_pred))
print("Precision :", precision_score(y_test, y_pred))
print("Recall :", recall_score(y_test, y_pred))
print("F1 Score :", f1_score(y_test, y_pred))

# %% [markdown]
# SVC

# %%
# SVC Classification using Breast Cancer Dataset

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score

df = pd.read_csv('C:/Users/Amal/OneDrive/Documents/Internship/Python/Feature Engineering/breast_cancer.csv')

data = pd.DataFrame(df)

print(data.head())
print(data.info())

data['diagnosis'] = data['diagnosis'].astype(str).str.strip()
data['diagnosis'] = data['diagnosis'].map({'M': 1, 'B': 0})

data.dropna(subset=['diagnosis'], inplace=True)
data.fillna(data.mean(numeric_only=True), inplace=True)

if 'id' in data.columns:
    data.drop('id', axis=1, inplace=True)

print(data.head())

data.dropna(axis=1, how='all', inplace=True)

x = data.drop('diagnosis', axis=1)
y = data['diagnosis']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

print(x_train.shape)
print(x_test.shape)

scaler = StandardScaler()

x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

model = SVC(kernel='rbf', C=100, gamma='auto',)
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

print(y_pred)

comparison = pd.DataFrame({
    'Actual': y_test,
    'Predicted': y_pred
})

print(comparison.head())

print("Accuracy :", accuracy_score(y_test, y_pred))
print("Confusion Matrix :")
print(confusion_matrix(y_test, y_pred))
print("Precision :", precision_score(y_test, y_pred))
print("Recall :", recall_score(y_test, y_pred))
print("F1 Score :", f1_score(y_test, y_pred))

# %% [markdown]
# Naive Bayes

# %%
# Naive Bayes Classification using play tennis Dataset

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score
from sklearn.preprocessing import OneHotEncoder

df = pd.read_csv('C:/Users/Amal/OneDrive/Documents/Internship/Machine Learning/Classification/Naive Bayes/play_tennis.csv')

data = pd.DataFrame(df)

print(data.head())
print(data.info())


data['play'] = data['play'].map({'Yes':1, 'No':0})
categorical_cols = ['outlook', 'temp','humidity','wind','day']
data.fillna(data.mean(numeric_only=True), inplace=True)

# One Hot Encoding
ohe = OneHotEncoder(handle_unknown='ignore',sparse_output=False).set_output(transform='pandas')
ohetransform = ohe.fit_transform(data[categorical_cols])
data = pd.concat([data, ohetransform], axis=1)
data.drop(categorical_cols, axis=1, inplace=True)

print(data.head())

x = data.drop('play', axis=1)
y = data['play']

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42 )

print(x_train.shape)
print(x_test.shape)

model = GaussianNB()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

print(y_pred)

comparison = pd.DataFrame({
    'Actual': y_test,
    'Predicted': y_pred
})

print(comparison.head())

# Confusion Metrics
print("Accuracy :", accuracy_score(y_test, y_pred))
print("Confusion Matrix :")
print(confusion_matrix(y_test, y_pred))
print("Precision :", precision_score(y_test, y_pred))
print("Recall :", recall_score(y_test, y_pred))
print("F1 Score :", f1_score(y_test, y_pred))

# %% [markdown]
# BIAS & VARIANCE
