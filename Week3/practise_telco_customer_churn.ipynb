# %%
import numpy as np
import pandas as pd

# %%
path = "/home/silvy_linux/Desktop/Internship/Datasets/WA_Fn-UseC_-Telco-Customer-Churn.csv"
customer_data_raw = pd.read_csv(path)
customer_data_raw.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
customer_data_raw.tail()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
customer_data_raw.isnull().sum()  #to check missing values
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
customer_data_raw.shape
# Out:
# (7043, 21)

# %%
customer_data_raw['Churn'].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
customer_who_stayed = customer_data_raw[customer_data_raw.Churn == "No"]
customer_who_left = customer_data_raw[customer_data_raw.Churn == "Yes"]

# %%
customer_who_stayed.shape
# Out:
# (5174, 21)

# %%
customer_who_left.shape
# Out:
# (1869, 21)

# %%
customer_who_stayed.head(3)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 3  No phone service             DSL            Yes  ...              Yes
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 3         Yes          No              No        One year               No
#
# ...

# %%
customer_who_left.head(3)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 4  9237-HQITU  Female              0      No         No       2          Yes
# 5  9305-CDSKC  Female              0      No         No       8          Yes
#
#   MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 2            No             DSL            Yes  ...               No
# 4            No     Fiber optic             No  ...               No
# 5           Yes     Fiber optic             No  ...              Yes
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 2          No          No              No  Month-to-month              Yes
# 4          No          No              No  Month-to-month              Yes
# 5          No         Yes             Yes  Month-to-month              Yes
#
#       PaymentMethod MonthlyCharges  TotalCharges Churn
# ...

# %% [markdown]
# undersampling , building a sampple dataset containing distribution of customer who left and customer who stayed
#
# no of customer who left = 1869

# %%
customer_who_stayed_reduced = customer_who_stayed.sample(n = 1869) #reduced the sample of people who stayed to match the count who left

# %%
customer_who_stayed_reduced.shape
# Out:
# (1869, 21)

# %%
new_data_set = pd.concat([customer_who_stayed_reduced,customer_who_left],axis = 0)

# %%
new_data_set['Churn'].value_counts()
# Out:
# Churn
# No     1869
# Yes    1869
# Name: count, dtype: int64

# %%
new_data_set.head(40)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 4429  3486-HOOGQ  Female              0     Yes        Yes      70
# 7     6713-OKOMC  Female              0      No         No      10
# 2025  1488-PBLJN  Female              0     Yes        Yes      72
# 3483  4465-VDKIQ  Female              0      No         No      18
# 3416  0603-OLQDC    Male              0      No        Yes      12
# 6335  7798-JVXYM  Female              0      No         No      14
# 1193  5232-NXPAY  Female              0      No         No      47
# 6366  2845-KDHVX  Female              0     Yes         No      64
# 1835  8356-WUAOJ  Female              0     Yes         No       1
# 3363  3474-BAFSJ    Male              0     Yes         No      57
# 3164  2603-HVKCG    Male              0      No         No      31
# 3110  6569-KTMDU  Female              0      No         No       1
# 3235  4825-XJGDM  Female              0      No         No      61
# ...
